# %%
from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams, LTTextBox, LTTextLine

# %%
fp = open('SHI 4-24-19 (internal use).pdf', 'rb')
    
parser = PDFParser(fp)
doc = PDFDocument()
parser.set_document(doc)
doc.set_parser(parser)
doc.initialize('')
rsrcmgr = PDFResourceManager()
laparams = LAParams()
laparams.char_margin = 1.0
laparams.word_margin = 1.0
device = PDFPageAggregator(rsrcmgr, laparams=laparams)
interpreter = PDFPageInterpreter(rsrcmgr, device)
extracted_text = ''

for page in doc.get_pages():
    interpreter.process_page(page)
    layout = device.get_result()
    for lt_obj in layout:
        if isinstance(lt_obj, LTTextBox) or isinstance(lt_obj, LTTextLine):
            extracted_text += lt_obj.get_text()
# Out:
# WARNING:pdfminer.layout:Too many boxes (103) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (125) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (125) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (111) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (102) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (109) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (118) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (125) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (125) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (118) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (104) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (111) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (117) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (124) to group, skipping.
# ...

# %%
print(extracted_text)
# Out:
# DEPARTMENT OF HOUSING AND COMMUNITY DEVELOPMENT CH40B SUBSIDIZED HOUSING INVENTORY
# Total SHI
# Units
# Affordability
# Expires
# Project Name
# Address
# Type
# Built w/
# Comp.
# Permit?
# Subsidizing
# Agency
# Abington
# DHCD
# ID #
# DHCD
# 71 Shaw Ave
# 71 Shaw Ave
# 70
# Yes
# Perp
# Rental
# 2
# DHCD
# n/a
# Green Street
# 1
# No
# Perp
# Rental
# 3
# DHCD
# n/a
# Dorsey Street
# 1
# No
# Perp
# Rental
# 4
# DHCD
# Beaver Brook
# Linwood St
# 4
# Yes
# Perp
# Ownership
# 5
# MassHousing
# Chestnut Glen
# 585 Chestnut St.
# 130
# No
# 2032*
# Rental
# 6
# EOHHS
# Mt. Laurel Lane
# Mt. Laurel Lane
# 4
# No
# 2028
# Rental
# 7
# MHP
# DHCD
# Woodlands at Abington Station
# 303 Sumner Street
# 192
# Yes
# Perp
# Rental
# 8
# MassHousing
# DDS
# DDS Group Homes
# Confidential
# 36
# No
# N/A
# Rental
# 4183
# DHCD
# Meadowbrook Estates
# George F. Gillespie Way
# 7
# YES
# Perp
# Ownership
# 9096
# DHCD
# Leavitt Terrace
# 100 Lincoln Boulevard
# 40
# NO
# Perp
# Rental
# 9664
# ...

# %%
# town name is always the fourteenth after "subsidizing"......
# census 2010 year round housing units follows HUD, town name
# percent subsidized follows that, totals
# total SHI units follows "percent subsidized"
